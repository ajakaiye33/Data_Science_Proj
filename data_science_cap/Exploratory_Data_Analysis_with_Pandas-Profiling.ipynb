# %%
# load packages
import pandas as pd
import numpy as np
import os
import warnings
import matplotlib.pyplot as plt
warnings.filterwarnings('ignore')
import pandas_profiling as pf
# %matplotlib inline

# %%
os.chdir('/Users/ajakaiye/Documents/')

# %%
heart_data = pd.read_csv('Master_Data_Analysis/Jupyter Notebooks/data/heart.csv')

# %%
heart_data.head()
# Out:
#    age     sex    chest_pain  rest_bp  chol  fbs  \
# 0   63    Male       typical      145   233    1
# 1   67    Male  asymptomatic      160   286    0
# 2   67    Male  asymptomatic      120   229    0
# 3   37    Male    nonanginal      130   250    0
# 4   41  Female    nontypical      130   204    0
#
#                         rest_ecg  max_hr  exang  old_peak  slope   ca  \
# 0  left ventricular hypertrophy      150      0       2.3      3  0.0
# 1  left ventricular hypertrophy      108      1       1.5      2  3.0
# 2  left ventricular hypertrophy      129      1       2.6      2  2.0
# 3                         normal     187      0       3.5      3  0.0
# 4  left ventricular hypertrophy      172      0       1.4      1  0.0
#
#          thal  disease
# 0       fixed        0
# 1      normal        1
# 2  reversable        1
# 3      normal        0
# 4      normal        0

# %%
heart_data.tail()
# Out:
#      age     sex    chest_pain  rest_bp  chol  fbs  \
# 298   45    Male       typical      110   264    0
# 299   68    Male  asymptomatic      144   193    1
# 300   57    Male  asymptomatic      130   131    0
# 301   57  Female    nontypical      130   236    0
# 302   38    Male    nonanginal      138   175    0
#
#                           rest_ecg  max_hr  exang  old_peak  slope   ca  \
# 298                         normal     132      0       1.2      2  0.0
# 299                         normal     141      0       3.4      2  2.0
# 300                         normal     115      1       1.2      2  1.0
# 301  left ventricular hypertrophy      174      0       0.0      2  1.0
# 302                         normal     173      0       0.0      1  NaN
#
#            thal  disease
# 298  reversable        1
# 299  reversable        1
# 300  reversable        1
# 301      normal        1
# 302      normal        0

# %%
profile = pf.ProfileReport(heart_data)

# %%
profile.to_file(output_file='output.html')

# %%
profile
# Out:
#                 <iframe
#                     width="100%"
#                     height="800px"
#                     srcdoc="&lt;!doctype html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;utf-8&quot;&gt;
#     &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;
#     &lt;meta name=&quot;description&quot; content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;
#     &lt;meta name=&quot;author&quot; content=&quot;Jos Polfliet, Simon Brugman and the open source community.&quot;&gt;
#     &lt;meta name=&quot;generator&quot; content=&quot;Pandas Profiling 2.3.0&quot; /&gt;
#     &lt;meta name=&quot;url&quot; content=&quot;https://github.com/pandas-profiling/pandas-profiling&quot;&gt;
#
#     &lt;title&gt;Pandas Profiling Report&lt;/title&gt;
#
# &lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
# ...

# %%
heart_data.describe()
# Out:
#               age     rest_bp        chol         fbs      max_hr       exang  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.438944  131.689769  246.693069    0.148515  149.607261    0.326733
# std      9.038662   17.599748   51.776918    0.356198   22.875003    0.469794
# min     29.000000   94.000000  126.000000    0.000000   71.000000    0.000000
# 25%     48.000000  120.000000  211.000000    0.000000  133.500000    0.000000
# 50%     56.000000  130.000000  241.000000    0.000000  153.000000    0.000000
# 75%     61.000000  140.000000  275.000000    0.000000  166.000000    1.000000
# max     77.000000  200.000000  564.000000    1.000000  202.000000    1.000000
#
#          old_peak       slope          ca     disease
# count  303.000000  303.000000  299.000000  303.000000
# mean     1.039604    1.600660    0.672241    0.458746
# std      1.161075    0.616226    0.937438    0.499120
# ...

# %%
#missing values
heart_data.isnull().sum()*100
# Out:
# age             0
# sex             0
# chest_pain      0
# rest_bp         0
# chol            0
# fbs             0
# rest_ecg        0
# max_hr          0
# exang           0
# old_peak        0
# slope           0
# ca            400
# thal          200
# disease         0
# dtype: int64

# %%
#isolate columns with categorical variable,integer variable, continuous variable
heart_data.select_dtypes(include='int')
# Out:
#      age  rest_bp  chol  fbs  max_hr  exang  slope  disease
# 0     63      145   233    1     150      0      3        0
# 1     67      160   286    0     108      1      2        1
# 2     67      120   229    0     129      1      2        1
# 3     37      130   250    0     187      0      3        0
# 4     41      130   204    0     172      0      1        0
# ..   ...      ...   ...  ...     ...    ...    ...      ...
# 298   45      110   264    0     132      0      2        1
# 299   68      144   193    1     141      0      2        1
# 300   57      130   131    0     115      1      2        1
# 301   57      130   236    0     174      0      2        1
# 302   38      138   175    0     173      0      1        0
#
# [303 rows x 8 columns]

# %%
# continous variable
heart_data.select_dtypes(include='float64')
# Out:
#      old_peak   ca
# 0         2.3  0.0
# 1         1.5  3.0
# 2         2.6  2.0
# 3         3.5  0.0
# 4         1.4  0.0
# ..        ...  ...
# 298       1.2  0.0
# 299       3.4  2.0
# 300       1.2  1.0
# 301       0.0  1.0
# 302       0.0  NaN
#
# [303 rows x 2 columns]

# %%
#string/categorical variable
heart_data.select_dtypes(include='object')
# Out:
#         sex    chest_pain                       rest_ecg        thal
# 0      Male       typical  left ventricular hypertrophy        fixed
# 1      Male  asymptomatic  left ventricular hypertrophy       normal
# 2      Male  asymptomatic  left ventricular hypertrophy   reversable
# 3      Male    nonanginal                         normal      normal
# 4    Female    nontypical  left ventricular hypertrophy       normal
# ..      ...           ...                            ...         ...
# 298    Male       typical                         normal  reversable
# 299    Male  asymptomatic                         normal  reversable
# 300    Male  asymptomatic                         normal  reversable
# 301  Female    nontypical  left ventricular hypertrophy       normal
# 302    Male    nonanginal                         normal      normal
#
# [303 rows x 4 columns]
